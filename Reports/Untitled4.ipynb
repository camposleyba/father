# %%
import pandas as pd
import warnings
import re
import time


start = time.time()

warnings.filterwarnings('ignore')

robot_number_list = [
'ATA026',
'ATA053',
'ATA053',
'ATA104',
'ATA113',
'ATA151',
'ATA151',
'ATA155',
'ATA158',
'ATA187',
'ATA195',
'ATA247',
'ATA261',
'ATA265',
'ATA295',
'ATA317',
'ATA328',
'ATA340',
'ATA348',
'ATA350',
'ATA352',
'ATA376',
'ATA394',
'ATA394',
'ATA396',
'ATA397',
'ATA398',
'ATA399',
'ATA401',
'ATA406',
'ATA412',
'ATA417',
'ATA425',
'ATA430',
'ATA432',
'ATA435',
'ATA446',
'ATA450',
'ATA462',
'ATA467',
'ATA476',
'ATA477',
'ATA487',
'ATA493',
'ATA496',
'ATA499',
'ATA525',
'ATA526',
'ATA531',
'ATA531',
'ATA537',
'ATA538',
'ATA544',
'ATA550',
'ATA556',
'ATA557',
'ATA561',
'ATA563',
'ATA565',
'ATA566',
'ATA573',
'ATA574',
'ATA584',
'ATA594',
'ATA595',
'ATA596',
'ATA599',
'ATA608',
'ATA610',
'ATA617',
'ATA619',
'ATA622',
'ATA624',
'ATA626',
'ATA632',
'ATA637',
'ATA638',
'ATA639',
'ATA640',
'ATA646',
'ATA648',
'ATA651',
'ATA652',
'ATA653',
'ATA655',
'ATA658',
'ATA659',
'ATA660',
'ATA663',
'ATA672',
'ATA676',
'ATA680',
'ATA690',
'ATA696',
'ATA697',
'ATA700',
'ATA705',
'ATA708',
'ATA709',
'ATA711',
'ATA719',
'ATA719',
'ATA726',
'ATA727',
'ATA728',
'ATA733',
'ATA734',
'ATA741',
'ATA747',
'ATA753',
'ATA755',
'ATA757',
'ATA765',
'ATA766',
'ATA769',
'ATA770',
'ATA776',
'ATA788',
'ATA791',
'ATA792',
'ATA795',
'ATA796',
'ATA797',
'ATA798',
'ATA799',
'ATA800',
'ATA803',
'ATA805',
'ATA806',
'ATA808',
'ATA809',
'ATA811',
'ATA813',
'ATA816',
'ATA828',
'ATA831',
'ATA833',
'ATA835',
'ATA845',
'ATA152',
'ATA318',
'ATA431',
'ATA749',
'ODA117',
'ODA117',
'ODA127',
'ODA149',
'ODA169',
'ODA192']

df = pd.read_excel(r"C:\Users\016434613\Downloads\progress_dt_tasks_details_report.xlsx")

df = df.loc[:,['DSL/SUPERVISOR (NAME)','DSL/SUPERVISOR (EMAIL)','ROBOT NUMBER','REGIONS']]

df_2 = df.loc[df['ROBOT NUMBER'].isin(robot_number_list)]

df_2.to_excel(r"C:\Users\016434613\Desktop\para_fede.xlsx", index=False)
print("done!")
# Out:
# done!

# %%
import pandas as pd

data = pd.read_parquet(r"C:\Users\016434613\Downloads\test-00000-of-00001-a8d3e0d80611e4db.parquet", engine='pyarrow')
data
# Out:
#                                               question  \
# 0    You bought a limousine for $98,000 and are pla...
# 1    Arno Co. did not record a credit purchase of m...
# 2    Which of the following statements about audit ...
# 3    Which of the following procedures would an aud...
# 4    The FASB makes changes to the Accounting Stand...
# ..                                                 ...
# 277  Rigg Steele and Urco Corps. all accrual-basis ...
# 278  A CPA has been requested by a former audit cli...
# 279  A government entity is required to include a s...
# 280  In which of the following situations would the...
# 281  Bay Co. incurred legal fees in defending its p...
#
#                                                choices  answer  \
# 0                           [164%, 1.64%, 0.45%, 183%]       0
# 1    [No effect No effect, No effect Understated, U...       1
# 2    [Nonsampling risk arises from the possibility ...       1
# ...

# %%
# %pip install pyarrow
# Out:
# ...
#      ---------------------------------------- 21.5/21.5 MB 9.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\016434613\Python39\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
