# %%
import win32com.client
import sys
import subprocess
import time
import os
from Create_Credentials import createCredentials
import pandas as pd
import warnings
from openpyxl import load_workbook
#import XlsxWriter

warnings.filterwarnings('ignore')

class SapGUI():
    def __init__(self):
        self.sapconn = 'YPE-PROD   -ERP -ECC EHP4  -[ECCPROD]'
        self.path = r'C:\Program Files (x86)\SAP\FrontEnd\SAPgui\saplogon.exe'
        subprocess.Popen(self.path)
        time.sleep(5)
        
        self.SapGuiAuto = win32com.client.GetObject('SAPGUI')
        if not type(self.SapGuiAuto)== win32com.client.CDispatch:
            return
        
        application = self.SapGuiAuto.GetScriptingEngine
        
        self.connection = application.OpenConnection(self.sapconn, True)
        time.sleep(3)
        self.session = self.connection.children(0)
        self.session.FindById("wnd[0]").maximize
        
    def sapLogon(self):
        cr = createCredentials()
        dict_ = cr.load('SAP_Credentials')
        try:
            self.session.findById("wnd[0]/usr/txtRSYST-BNAME").text = dict_['user']
            self.session.findById("wnd[0]/usr/pwdRSYST-BCODE").text = dict_['password']
            self.session.findById("wnd[0]/usr/pwdRSYST-BCODE").setFocus
            self.session.findById("wnd[0]/usr/pwdRSYST-BCODE").caretPosition = 15
            self.session.findById("wnd[0]").sendVKey(0)
        except:
            print(sys.exc_info()[0])
            
    def searchTransaction(self, trns):
        try:
            self.session.findById("wnd[0]/tbar[0]/okcd").text = trns
            self.session.findById("wnd[0]").sendVKey(0) #enter
        except:
            print(sys.exc_info()[0])
            
    def pti_all_entity(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='PTI.XLSX'
        self.fullpath=self.filepath+self.filename
        try:
            self.session.findById("wnd[0]/shellcont/shell").expandNode("002")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").expandNode("000000001001")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "000000001317"
            self.session.findById("wnd[0]/shellcont/shell").topNode = "000000001298"
            self.session.findById("wnd[0]/shellcont/shell").doubleClickNode("000000001317")
            self.session.findById("wnd[0]").sendVKey(8) #execute
            time.sleep(1)
            self.session.findById("wnd[0]").sendVKey(33)
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER").setFocus
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").currentCellRow = 80
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").firstVisibleRow = 75
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").selectedRows = "80"
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").clickCurrentCell()
            self.session.findById("wnd[0]").sendVKey(43)
            self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ctxtDY_PATH").text = self.filepath
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = self.filename
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 8
            
            if os.path.exists(self.fullpath):
                self.session.findById("wnd[1]").sendVKey(11)
            else:
                self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(3)
            subprocess.Popen("taskkill /F /IM EXCEL.EXE",shell=True)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            time.sleep(3)
        except:
            print(sys.exc_info()[0])
    
    def USGAAP_YE(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='USGAAP RESULTS.XLSX'
        self.fullpath=self.filepath+self.filename
        try:
            self.session.findById("wnd[0]/shellcont/shell").expandNode("002")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").expandNode("000000001001")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "000000001054"
            self.session.findById("wnd[0]/shellcont/shell").topNode = "000000001050"
            self.session.findById("wnd[0]/shellcont/shell").doubleClickNode("000000001054")
            self.session.findById("wnd[0]").sendVKey(0)
            time.sleep(1)
            self.session.findById("wnd[0]/usr/ctxtU3_00011-LOW").text = "300000"
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").text = "399999"
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").setFocus
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").caretPosition = 6
            self.session.findById("wnd[0]/tbar[1]/btn[8]").press()
            self.session.findById("wnd[0]/tbar[1]/btn[33]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").currentCellRow = 104
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").firstVisibleRow = 97
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").selectedRows = "104"
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").clickCurrentCell()
            self.session.findById("wnd[0]/tbar[1]/btn[43]").press()
            self.session.findById("wnd[1]/tbar[0]/btn[0]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ctxtDY_PATH").text = self.filepath
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = self.filename
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 19
            if os.path.exists(self.fullpath):
                self.session.findById("wnd[1]").sendVKey(11)
            else:
                self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(3)
            subprocess.Popen("taskkill /F /IM EXCEL.EXE",shell=True)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            time.sleep(3)
        except:
            print(sys.exc_info()[0])
    
    def LOCAL_GAAP_YE(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='LOCAL GAAP RESULTS.XLSX'
        self.fullpath=self.filepath+self.filename
        try:
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "002"
            self.session.findById("wnd[0]/shellcont/shell").collapseNode("002")
            self.session.findById("wnd[0]/shellcont/shell").expandNode("006")
            self.session.findById("wnd[0]/shellcont/shell").expandNode("000000001387")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "000000001396"
            self.session.findById("wnd[0]/shellcont/shell").doubleClickNode("000000001396")
            time.sleep(1)
            self.session.findById("wnd[0]/usr/ctxtU3_00011-LOW").text = "100000"
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").text = "299999"
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").setFocus
            self.session.findById("wnd[0]/usr/ctxtU3_00011-HIGH").caretPosition = 6
            self.session.findById("wnd[0]/tbar[1]/btn[8]").press()
            self.session.findById("wnd[0]/tbar[1]/btn[33]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").currentCellRow = 48
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").firstVisibleRow = 47
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").selectedRows = "48"
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").clickCurrentCell()
            self.session.findById("wnd[0]/tbar[1]/btn[43]").press()
            self.session.findById("wnd[1]/tbar[0]/btn[0]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ctxtDY_PATH").text = self.filepath
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = self.filename
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 23
            if os.path.exists(self.fullpath):
                self.session.findById("wnd[1]").sendVKey(11)
            else:
                self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(3)
            subprocess.Popen("taskkill /F /IM EXCEL.EXE",shell=True)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            time.sleep(3)
        except:
            print(sys.exc_info()[0])
    
    def GAAP_COMPARE(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='GAAP COMPARISON RESULTS.XLSX'
        self.fullpath=self.filepath+self.filename
        try:
            self.session.findById("wnd[0]/tbar[1]/btn[17]").press()
            self.session.findById("wnd[1]/usr/txtENAME-LOW").text = ""
            self.session.findById("wnd[1]/usr/txtENAME-LOW").setFocus
            self.session.findById("wnd[1]/usr/txtENAME-LOW").caretPosition = 0
            self.session.findById("wnd[1]/tbar[0]/btn[8]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/cntlALV_CONTAINER_1/shellcont/shell").currentCellRow = 3
            self.session.findById("wnd[1]/usr/cntlALV_CONTAINER_1/shellcont/shell").selectedRows = "3"
            self.session.findById("wnd[1]/tbar[0]/btn[2]").press()
            self.session.findById("wnd[0]/tbar[1]/btn[8]").press()
            self.session.findById("wnd[0]/tbar[1]/btn[43]").press()
            self.session.findById("wnd[1]/tbar[0]/btn[0]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ctxtDY_PATH").text = self.filepath
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = self.filename
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 28
            if os.path.exists(self.fullpath):
                self.session.findById("wnd[1]").sendVKey(11)
            else:
                self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(3)
            subprocess.Popen("taskkill /F /IM EXCEL.EXE",shell=True)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[1]/usr/btnSPOP-OPTION1").press()
            self.session.findById("wnd[0]").sendVKey(3)
            time.sleep(3)
        except:
            print(sys.exc_info()[0])
    
    def BS_MVMT_YE(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='BS MOVEMENT SUMMARY.XLSX'
        self.fullpath=self.filepath+self.filename
        try:
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "006"
            self.session.findById("wnd[0]/shellcont/shell").collapseNode("006")
            self.session.findById("wnd[0]/shellcont/shell").expandNode("002")
            self.session.findById("wnd[0]/shellcont/shell").topNode = "ROOT"
            self.session.findById("wnd[0]/shellcont/shell").expandNode("000000001022")
            self.session.findById("wnd[0]/shellcont/shell").selectedNode = "000000001028"
            self.session.findById("wnd[0]/shellcont/shell").topNode = "000000001022"
            self.session.findById("wnd[0]/shellcont/shell").doubleClickNode("000000001028")
            time.sleep(1)
            self.session.findById("wnd[0]/tbar[1]/btn[8]").press()
            self.session.findById("wnd[0]/tbar[1]/btn[33]").press()
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").currentCellRow = 3
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").selectedRows = "3"
            self.session.findById("wnd[1]/usr/ssubD0500_SUBSCREEN:SAPLSLVC_DIALOG:0501/cntlG51_CONTAINER/shellcont/shell").clickCurrentCell()
            self.session.findById("wnd[0]/tbar[1]/btn[43]").press()
            self.session.findById("wnd[1]/tbar[0]/btn[0]").press()
            time.sleep(1)
            self.session.findById("wnd[1]/usr/ctxtDY_PATH").text = "C:\\Users\\016434613\\Desktop\\"
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = "BS MOVEMENT SUMMARY.XLSX"
            self.session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 24
            if os.path.exists(self.fullpath):
                self.session.findById("wnd[1]").sendVKey(11)
            else:
                self.session.findById("wnd[1]").sendVKey(0)
            time.sleep(3)
            subprocess.Popen("taskkill /F /IM EXCEL.EXE",shell=True)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            self.session.findById("wnd[0]").sendVKey(3)
            subprocess.Popen("taskkill /f /im saplogon.exe",shell=True)
        except:
            print(sys.exc_info()[0])

class consol_summarize():
    def __init__(self):
        self.path_=r'C:\Users\016434613\Desktop\ALLCCCC_2022.xlsx'
    def pti_all_entity_consol(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='PTI.XLSX'
        self.fullpath=self.filepath+self.filename
        df = pd.read_excel(self.fullpath,sheet_name="Sheet1",converters={'Company Code':str})
        df = df.loc[:,['Company Code','Currency','AccumBal.Prev.Period','Debit   1-  2','Credit   1-  2','Accumulated balance']]
        df = df.groupby(['Company Code','Currency'])['AccumBal.Prev.Period','Debit   1-  2','Credit   1-  2','Accumulated balance'].sum().reset_index()
        df.to_excel(self.path_,index=False ,sheet_name = 'PTI')
        
    def usgaap_results_consol(self):
        self.filepath='C:\\Users\\016434613\\Desktop\\'        
        self.filename='USGAAP RESULTS.XLSX'
        self.fullpath=self.filepath+self.filename
        df = pd.read_excel(self.fullpath,sheet_name="Sheet1",converters={'Company Code':str})
        df = df.loc[:,['Company Code','Account Number','AccumBal.Prev.Period','Debit   1- 13','Credit   1- 13','Accumulated balance']]
        df['Account Number'] = df['Account Number'].apply(lambda x: x[5:])
        df = df.groupby(['Company Code','Account Number'])['AccumBal.Prev.Period','Debit   1- 13','Credit   1- 13','Accumulated balance'].sum().reset_index()
        book = load_workbook(self.path_)
        writer = pd.ExcelWriter(self.path_, engine = 'openpyxl')
        writer.book = book
        df.to_excel(writer, sheet_name = 'USGAAP', index=False)
        writer.save()
        writer.close()
            
#sap = SapGUI()
#sap.sapLogon()
#sap.searchTransaction('FGI0')
#sap.pti_all_entity()
#sap.USGAAP_YE()
#sap.LOCAL_GAAP_YE()
#sap.searchTransaction('GCAC')
#sap.GAAP_COMPARE()
#sap.searchTransaction('FGI0')
#sap.BS_MVMT_YE()
cs = consol_summarize()
#df1 = cs.usgaap_results_consol()
cs.pti_all_entity_consol()
cs.usgaap_results_consol()

# %%
import subprocess
subprocess.Popen("taskkill /f /im saplogon.exe",shell=True)
# Out:
# <Popen: returncode: None args: 'taskkill /f /im saplogon.exe'>

# %%
"C:\Users\016434613\Desktop\USGAAP RESULTS.XLSX"
