# %%
import pandas as pd
import numpy as np
import glob
import re
from urllib import request as req
import json



mgrname = {'681658897':'Alison Yara'}
reportnames = []
reportserial = []
isMgr = []

request = req.urlopen("https://unified-profile-api.us-south-k8s.intranet.ibm.com/v3/profiles/681658897/teamResolved")
datos = request.read().decode()
dictdatos = json.loads(datos)
reports = dictdatos['content']['functional']['reports']
for r in reports:
    #method setdefault(key,[]) sirve para poner una primera key con una lista vacia, si no, tira error de que no existe la key
    reportnames.append(r['nameDisplay'])
    reportserial.append(r['uid'])
    isMgr.append(r['isManager'])
    
#reportlist = devnames['Alison Yara']

df_Yara = pd.DataFrame(reportnames, columns=['Reports'])
df_Yara['Serials'] = reportserial
df_Yara['isManger'] = isMgr
df_Yara['Manager'] = "Alison Yara"

reportnames_ = []
reportserial_ = []
isMgr_ = []
mgr = []


for i in range(df_Yara['Reports'].size):
    request = req.urlopen("https://unified-profile-api.us-south-k8s.intranet.ibm.com/v3/profiles/"+df_Yara['Serials'][i]+"/teamResolved")
    datos = request.read().decode()
    dictdatos = json.loads(datos)
    try:
        reports = dictdatos['content']['functional']['reports']
        for r in reports:
            #method setdefault(key,[]) sirve para poner una primera key con una lista vacia, si no, tira error de que no existe la key
            reportnames_.append(r['nameDisplay'])
            reportserial_.append(r['uid'])
            isMgr_.append(r['isManager'])
            mgr.append(df_Yara['Reports'][i])
    except:
        pass

df_Reports = pd.DataFrame(reportnames_, columns=['Reports'])
df_Reports['Serials'] = reportserial_
df_Reports['isManger'] = isMgr_
df_Reports['Manager'] = mgr

reportnames_2 = []
reportserial_2 = []
isMgr_2 = []
mgr_ = []

for i in range(df_Reports['Reports'].size):
    request = req.urlopen("https://unified-profile-api.us-south-k8s.intranet.ibm.com/v3/profiles/"+df_Reports['Serials'][i]+"/teamResolved")
    datos = request.read().decode()
    dictdatos = json.loads(datos)
    try:
        reports = dictdatos['content']['functional']['reports']
        for r in reports:
            #method setdefault(key,[]) sirve para poner una primera key con una lista vacia, si no, tira error de que no existe la key
            reportnames_2.append(r['nameDisplay'])
            reportserial_2.append(r['uid'])
            isMgr_2.append(r['isManager'])
            mgr_.append(df_Reports['Reports'][i])
    except:
        pass

df_Reports_2 = pd.DataFrame(reportnames_2, columns=['Reports'])
df_Reports_2['Serials'] = reportserial_2
df_Reports_2['isManger'] = isMgr_2
df_Reports_2['Manager'] = mgr_

reportnames_2 = []
reportserial_2 = []
isMgr_2 = []
mgr_ = []

for i in range(df_Reports_2['Reports'].size):
    request = req.urlopen("https://unified-profile-api.us-south-k8s.intranet.ibm.com/v3/profiles/"+df_Reports_2['Serials'][i]+"/teamResolved")
    datos = request.read().decode()
    dictdatos = json.loads(datos)
    try:
        reports = dictdatos['content']['functional']['reports']
        for r in reports:
            #method setdefault(key,[]) sirve para poner una primera key con una lista vacia, si no, tira error de que no existe la key
            reportnames_2.append(r['nameDisplay'])
            reportserial_2.append(r['uid'])
            isMgr_2.append(r['isManager'])
            mgr_.append(df_Reports_2['Reports'][i])
    except:
        pass

df_Reports_3 = pd.DataFrame(reportnames_2, columns=['Reports'])
df_Reports_3['Serials'] = reportserial_2
df_Reports_3['isManger'] = isMgr_2
df_Reports_3['Manager'] = mgr_
    
    
df_all = df_Yara.append(df_Reports)
df_all = df_all.append(df_Reports_2)
df_all = df_all.append(df_Reports_3)


df_all.to_excel(r"C:\Users\016434613\Desktop\All_report.xlsx", index=False)

# %%
request = req.urlopen("https://unified-profile-api.us-south-k8s.intranet.ibm.com/v3/profiles/A69412693/teamResolved")
datos = request.read().decode()
dictdatos = json.loads(datos)
try:
    reports = dictdatos['content']['functional']['reports']
except:
    pass
# Out:
# No tiene reportes
